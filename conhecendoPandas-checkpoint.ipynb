# %% [markdown]
# # Conhecendo Pandas

# %% [markdown]
# Series

# %%
import pandas as pd
import numpy as np

# %%
pd.Series([1, 2, 3, 4, 5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
pd.Series((1, 2, 3, 4, 5))
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
serie = pd.Series([100, 120, 130, 150], index = [2018, 2019, 2020, 2021], dtype = float, name = 'Serie')

# %%
serie
# Out:
# 2018    100.0
# 2019    120.0
# 2020    130.0
# 2021    150.0
# Name: Serie, dtype: float64

# %%
np.random.normal(10, 5, 100)
# Out:
# array([ 9.29023651,  0.22181732, -0.6099014 ,  5.89711852,  8.74237374,
#        12.6691317 , 18.08197495,  2.3200029 , 18.52426139,  7.20450624,
#         9.27546707, 20.31675745,  2.53753722, 12.67382394, 12.07576764,
#        13.41797395, 10.42660822,  2.5853    , 12.65971641,  6.10237135,
#        10.95538483, 16.08073566, 11.92023573, 10.16175901, 13.32332675,
#        13.32557861, 11.55866071, 11.89285245,  2.08418009,  2.79139345,
#        14.48946374, 15.10297924,  6.31964563,  5.69139761, 22.53946914,
#         6.80824271, 14.79396759, 15.81279527, 11.84401806,  7.02326784,
#         4.46918464,  2.35114612,  3.80880268, 11.23094686,  4.90675167,
#         2.58345657,  9.87388029, 12.14027883,  7.53531828, 15.42059689,
#        13.20064678, 19.4460418 ,  8.85090888, 24.69067965,  6.64991319,
#        16.29265972, 12.99272381,  0.77507845,  7.48074715, 10.23378013,
#         0.95754959,  5.65137053,  8.88043224, 10.52813813,  2.23846868,
#         7.30439656, 20.57559814, 14.67566003,  7.55863151,  8.83886732,
#        12.5997654 , 14.59832614, 15.10522752, 18.0457307 , 10.62800935,
#         5.60695264,  5.51922861,  3.59348847,  7.28629637, 18.40464695,
#        13.65709769, 11.31944111, 21.02081324,  9.87839158,  4.59905948,
#         3.80561434,  9.03180064,  9.59195809,  6.53659267, 12.21066385,
#         9.93323747,  7.90187357, 17.9045491 ,  8.79472117,  9.71918065,
#         8.53078271, 10.86997006, 14.29618112,  5.68945945,  3.64627839])

# %%
np.random.seed(19)
s = pd.Series(np.random.normal(10, 5, 100), index = range(1, 101))

# %%
s
# Out:
# 1      10.750325
# 2       5.762722
# 3      11.759370
# 4      -1.524662
# 5       9.973096
#          ...
# 96      6.510294
# 97      3.095845
# 98      7.834424
# 99      9.383773
# 100     6.337457
# Length: 100, dtype: float64

# %%
s
# Out:
# 1      11.105016
# 2       8.297675
# 3       7.111257
# 4       7.979842
# 5       6.983553
#          ...
# 96     12.016779
# 97      5.483247
# 98      9.745796
# 99     15.266913
# 100     3.051569
# Length: 100, dtype: float64

# %%
s
# Out:
# 1      11.105016
# 2       8.297675
# 3       7.111257
# 4       7.979842
# 5       6.983553
#          ...
# 96     12.016779
# 97      5.483247
# 98      9.745796
# 99     15.266913
# 100     3.051569
# Length: 100, dtype: float64

# %%
s.axes
# Out:
# [RangeIndex(start=1, stop=101, step=1)]

# %%
s.dtype
# Out:
# dtype('float64')

# %%
s.ndim
# Out:
# 1

# %%
s.empty
# Out:
# False

# %%
s.size
# Out:
# 100

# %%
s.head()
# Out:
# 1    11.105016
# 2     8.297675
# 3     7.111257
# 4     7.979842
# 5     6.983553
# dtype: float64

# %%
s.tail()
# Out:
# 96     12.016779
# 97      5.483247
# 98      9.745796
# 99     15.266913
# 100     3.051569
# dtype: float64

# %%
s[1]
# Out:
# 11.105016313410745

# %%
serie[2018]
# Out:
# 100.0

# %%
s[1:5]
# Out:
# 2    8.297675
# 3    7.111257
# 4    7.979842
# 5    6.983553
# dtype: float64

# %%
s[:5]
# Out:
# 1    11.105016
# 2     8.297675
# 3     7.111257
# 4     7.979842
# 5     6.983553
# dtype: float64

# %%
s[1:5]
# Out:
# 2    8.297675
# 3    7.111257
# 4    7.979842
# 5    6.983553
# dtype: float64

# %%
s.head()
# Out:
# 1    11.105016
# 2     8.297675
# 3     7.111257
# 4     7.979842
# 5     6.983553
# dtype: float64

# %%
s.sum()
# Out:
# 1012.1617828660301

# %%
s.cumsum()
# Out:
# 1        11.105016
# 2        19.402691
# 3        26.513949
# 4        34.493791
# 5        41.477344
#           ...
# 96      978.614258
# 97      984.097505
# 98      993.843301
# 99     1009.110214
# 100    1012.161783
# Length: 100, dtype: float64

# %%
s.cumprod()
# Out:
# 1      1.110502e+01
# 2      9.214582e+01
# 3      6.552726e+02
# 4      5.228972e+03
# 5      3.651680e+04
#            ...
# 96     1.311407e+92
# 97     7.190770e+92
# 98     7.007978e+93
# 99     1.069902e+95
# 100    3.264879e+95
# Length: 100, dtype: float64

# %%
s.min()
# Out:
# 1.1967320271718993

# %%
s.max()
# Out:
# 19.89204374689137

# %%
s.idxmin()
# Out:
# 55

# %%
s.idxmax()
# Out:
# 31

# %%
s.mean()
# Out:
# 10.1216178286603

# %%
s.median()
# Out:
# 10.096567855662864

# %%
s.var()
# Out:
# 18.32918279252638

# %%
s.std()
# Out:
# 4.281259486707899

# %%
s.mad()
# Out:
# 3.4919596496984115

# %%
s.describe()
# Out:
# count    100.000000
# mean      10.121618
# std        4.281259
# min        1.196732
# 25%        6.931314
# 50%       10.096568
# 75%       12.755882
# max       19.892044
# dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (15,5))
s.plot(color = 'green', lw = 3, marker ='o', markersize = 5)
plt.xlabel('Eixo X')
plt.xlabel('Eixo Y')
plt.title('Grafico Series', fontsize = 20, color = 'Blue', pad = 15)
plt.grid(color = 'yellow', ls = '--')
plt.show()

# %%
s.plot(kind = 'hist', bins= 30)
plt.show()

# %%
plt.figure(figsize = (15,5))
s.plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize = (15,5))
s.plot(kind = 'kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
plt.figure(figsize = (15,5))
s.plot.line()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize = (15,5))
s.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
plt.figure(figsize = (15,5))
s.plot.bar()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize = (15,5))
s.plot.area()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize = (15,5))
s.plot.barh()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize = (15,10))
s.plot.pie()
# Out:
# <AxesSubplot:ylabel='None'>

# %%
plt.figure(figsize = (15,5))
s.plot.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11068/3030414697.py in <module>
#       1 plt.figure(figsize = (15,5))
# ----> 2 s.plot.scatter()
#
# TypeError: scatter() missing 2 required positional arguments: 'x' and 'y'
